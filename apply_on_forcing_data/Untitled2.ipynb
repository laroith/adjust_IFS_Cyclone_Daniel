# %%
import xarray as xr
import numpy as np
import argparse
from pathlib import Path
import glob

file_cas = xr.open_dataset("cas2023090100.nc")

ts = file_cas['T_SKIN'] - 1.3
fr_land = file_cas['FR_LAND']

file_cas['T_SKIN'] = xr.where(fr_land <= 0.05, file_cas['T_SKIN'] - 1.3, file_cas['T_SKIN'])

file_cas['T_SKIN']
# Out:
# <xarray.DataArray 'T_SKIN' (time: 1, lat: 224, lon: 544)>
# array([[[301.67834, 301.65295, 301.40686, ..., 295.49982, 297.16974,
#          297.30255],
#         [301.6256 , 301.38538, 301.42053, ..., 295.6463 , 296.76544,
#          295.9588 ],
#         [301.38147, 301.28967, 301.3971 , ..., 297.4881 , 296.43146,
#          295.5916 ],
#         ...,
#         [268.65942, 267.63474, 266.61005, ..., 271.43988, 271.46127,
#          271.48865],
#         [274.13123, 274.1407 , 274.12878, ..., 271.5177 , 271.54425,
#          271.5708 ],
#         [273.13312, 273.19672, 273.26028, ..., 271.73187, 271.74536,
#          271.75882]]], dtype=float32)
# Coordinates:
#   * lat      (lat) float32 19.25 19.53 19.81 20.09 ... 81.08 81.36 81.64 81.92
#   * lon      (lon) float32 -68.91 -68.62 -68.34 -68.06 ... 83.25 83.53 83.81
#   * time     (time) datetime64[ns] 2023-09-01

# %%
# Out:
# <xarray.DataArray 'T_SKIN' ()>
# array(302.41815, dtype=float32)
# Coordinates:
#     lat      float32 24.87
#     lon      float32 -63.28
#     time     datetime64[ns] 2023-09-01

# %%
file_cas_new=xr.open_dataset("cas2023090100.nc")
    

file_cas_new['T_SKIN']
# Out:
# <xarray.DataArray 'T_SKIN' (time: 1, lat: 224, lon: 544)>
# [121856 values with dtype=float32]
# Coordinates:
#   * lat      (lat) float32 19.25 19.53 19.81 20.09 ... 81.08 81.36 81.64 81.92
#   * lon      (lon) float32 -68.91 -68.62 -68.34 -68.06 ... 83.25 83.53 83.81
#   * time     (time) datetime64[ns] 2023-09-01

# %%
diff = file_cas_new['T_SKIN'] - file_cas['T_SKIN']
diff
# Out:
# <xarray.DataArray 'T_SKIN' (time: 1, lat: 224, lon: 544)>
# array([[[1.2999878, 1.2999878, 1.2999878, ..., 0.       , 0.       ,
#          0.       ],
#         [1.2999878, 1.2999878, 1.2999878, ..., 0.       , 0.       ,
#          0.       ],
#         [1.2999878, 1.2999878, 1.2999878, ..., 0.       , 0.       ,
#          0.       ],
#         ...,
#         [0.       , 0.       , 0.       , ..., 1.2999878, 1.2999878,
#          1.2999878],
#         [0.       , 0.       , 0.       , ..., 1.2999878, 1.2999878,
#          1.2999878],
#         [0.       , 0.       , 0.       , ..., 1.2999878, 1.2999878,
#          1.2999878]]], dtype=float32)
# Coordinates:
#   * lat      (lat) float32 19.25 19.53 19.81 20.09 ... 81.08 81.36 81.64 81.92
#   * lon      (lon) float32 -68.91 -68.62 -68.34 -68.06 ... 83.25 83.53 83.81
#   * time     (time) datetime64[ns] 2023-09-01
